# %% [markdown]
# # Ejercicio 2¶

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
G=nx.read_gml('dolphins.gml')
nx.draw(G, with_labels=False, font_weight='bold',node_size=50)
plt.show()
#list(G)
# Out:
# ['Ripplefluke',
#  'SN100',
#  'Fish',
#  'Hook',
#  'CCL',
#  'Vau',
#  'Jet',
#  'Shmuddel',
#  'Beescratch',
#  'Feather',
#  'DN16',
#  'Mus',
#  'Kringel',
#  'Jonah',
#  'Notch',
#  'SMN5',
#  'TR99',
#  'Patchback',
#  'DN21',
#  'Gallatin',
#  'Topless',
#  'SN96',
#  'MN60',
#  'MN23',
#  'Beak',
#  'Wave',
#  'Zap',
#  'Double',
#  'TSN103',
#  'MN105',
#  'Thumper',
#  'Fork',
#  'Bumper',
#  'Five',
#  'Oscar',
#  'SN90',
#  'Knit',
#  'Trigger',
#  'TR77',
#  'SN63',
#  'Zig',
#  'TR88',
#  'Cross',
#  'MN83',
#  'Scabs',
#  'Zipfel',
#  'TR82',
#  'DN63',
#  'Grin',
#  'Haecksel',
#  'Number1',
#  'SN89',
#  'TSN83',
#  'TR120',
#  'Upbang',
#  'PL',
#  'SN4',
#  'Quasi',
#  'Stripes',
#  'Whitetip',
#  'SN9',
#  'Web']

# %%
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

data_gender=ldata('dolphinsGender.txt')

data_gender
colores=[]

#le agregamos el atributo "genero" al grafo G
for elemento in data_gender:
    G.node[elemento[0]]['genero']=elemento[1]
    
#creamos un vector de colores que vincula los generos (mismo orden)     
for gen in nx.get_node_attributes(G, "genero").values():
    if gen=='f':
        colores.append('red')
    elif gen=='m':
        colores.append('blue')
    else:
        colores.append('grey')

# %%
#verificamos el vector colores
nx.get_node_attributes(G, "genero").values()
# Out:
# dict_values(['NA', 'f', 'f', 'f', 'f', 'f', 'm', 'm', 'f', 'm', 'f', 'm', 'm', 'm', 'f', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'f', 'NA', 'f', 'f', 'm', 'm', 'm', 'm', 'f', 'm', 'm', 'm', 'f', 'f', 'm', 'm', 'm', 'm', 'f', 'm', 'NA', 'f', 'm', 'f', 'm', 'm', 'm', 'm', 'f', 'NA', 'f', 'm', 'm', 'f', 'f', 'f', 'f', 'f', 'm'])

# %%
nx.draw(G, with_labels=False,node_color=colores, font_weight='bold',node_size=50)
plt.show()

# %%
colores
# Out:
# ['red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'grey',
#  'blue',
#  'grey',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'grey',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'grey',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red']

# %%
# Out:
# [['Five', 'f'],
#  ['Cross', 'm'],
#  ['SMN5', 'm'],
#  ['MN83', 'm'],
#  ['Trigger', 'f'],
#  ['Patchback', 'm'],
#  ['Vau', 'f'],
#  ['Fork', 'm'],
#  ['TR120', 'f'],
#  ['MN105', 'm'],
#  ['Haecksel', 'm'],
#  ['MN60', 'm'],
#  ['Stripes', 'f'],
#  ['Jonah', 'm'],
#  ['TSN103', 'f'],
#  ['Topless', 'm'],
#  ['Scabs', 'f'],
#  ['TR99', 'f'],
#  ['Shmuddel', 'f'],
#  ['TSN83', 'NA'],
#  ['Grin', 'm'],
#  ['Zap', 'NA'],
#  ['SN9', 'f'],
#  ['SN4', 'f'],
#  ['SN63', 'f'],
#  ['Hook', 'f'],
#  ['Whitetip', 'f'],
#  ['Kringel', 'f'],
#  ['Zipfel', 'm'],
#  ['SN89', 'f'],
#  ['SN100', 'f'],
#  ['Double', 'f'],
#  ['CCL', 'f'],
#  ['Thumper', 'm'],
#  ['Beak', 'm'],
#  ['Fish', 'f'],
#  ['Oscar', 'm'],
#  ['TR77', 'f'],
#  ['SN96', 'm'],
#  ['Bumper', 'm'],
#  ['PL', 'm'],
#  ['TR82', 'NA'],
#  ['DN16', 'f'],
#  ['Web', 'm'],
#  ['SN90', 'm'],
#  ['Beescratch', 'm'],
#  ['Wave', 'f'],
#  ['Feather', 'm'],
#  ['Gallatin', 'm'],
#  ['Upbang', 'm'],
#  ['DN63', 'm'],
#  ['DN21', 'm'],
#  ['Jet', 'm'],
#  ['Number1', 'm'],
#  ['Knit', 'm'],
#  ['Zig', 'm'],
#  ['Ripplefluke', 'NA'],
#  ['MN23', 'm'],
#  ['Quasi', 'm'],
#  ['Mus', 'm'],
#  ['Notch', 'm'],
#  ['TR88', 'f']]
