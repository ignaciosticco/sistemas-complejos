# %% [markdown]
# # Ejercicio 2¶

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
G=nx.read_gml('dolphins.gml')
nx.draw(G, with_labels=False, font_weight='bold',node_size=50)
plt.show()
#list(G)

# %%
def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

data_gender=ldata('dolphinsGender.txt')

data_gender
colores=[]

#le agregamos el atributo "genero" al grafo G
for elemento in data_gender:
    G.node[elemento[0]]['genero']=elemento[1]
    
#creamos un vector de colores que vincula los generos (mismo orden)     
for gen in nx.get_node_attributes(G, "genero").values():
    if gen=='f':
        colores.append('red')
    elif gen=='m':
        colores.append('blue')
    else:
        colores.append('grey')

# %%
#verificamos el vector colores
#nx.get_node_attributes(G, "genero").values()

### Asi se accede a las propiedades de un nodo G.node['Ripplefluke']

# %%
nx.draw(G, with_labels=False,node_color=colores, font_weight='bold',node_size=70,node_grouping='genero')
plt.show()

# %%
nodes = nx.get_node_attributes(G, "genero").values()
print(" Arriba:",list(G.nodes(data=True)))
j=0
while j<2:
    random.shuffle(nodes)
    i=0
    for n in G:
        G.node[n]['genero']= nodes[i]
        i+=1
    print("  ")
    print(" Abajo:",list(G.nodes(data=True)))
    j+=1
comp = nx.girvan_newman(G)
# Out:
# (' Arriba:', [(u'Haecksel', {'genero': 'm'}), (u'Web', {'genero': 'f'}), (u'Jet', {'genero': 'm'}), (u'SMN5', {'genero': 'NA'}), (u'DN16', {'genero': 'm'}), (u'Shmuddel', {'genero': 'f'}), (u'Cross', {'genero': 'm'}), (u'Topless', {'genero': 'f'}), (u'Beescratch', {'genero': 'm'}), (u'CCL', {'genero': 'f'}), (u'Quasi', {'genero': 'f'}), (u'MN60', {'genero': 'f'}), (u'Feather', {'genero': 'm'}), (u'Wave', {'genero': 'm'}), (u'SN9', {'genero': 'f'}), (u'Fork', {'genero': 'm'}), (u'Mus', {'genero': 'm'}), (u'DN63', {'genero': 'm'}), (u'DN21', {'genero': 'f'}), (u'SN89', {'genero': 'f'}), (u'MN23', {'genero': 'm'}), (u'Stripes', {'genero': 'f'}), (u'Jonah', {'genero': 'm'}), (u'Zap', {'genero': 'm'}), (u'Five', {'genero': 'm'}), (u'Beak', {'genero': 'm'}), (u'Vau', {'genero': 'f'}), (u'Knit', {'genero': 'm'}), (u'TSN103', {'genero': 'f'}), (u'Grin', {'genero': 'f'}), (u'TR82', {'genero': 'm'}), (u'TR77', {'genero': 'm'}), (u'Double', {'genero': 'm'}), (u'Number1', {'genero': 'm'}), (u'Thumper', {'genero': 'f'}), (u'SN63', {'genero': 'm'}), (u'Trigger', {'genero': 'f'}), (u'Zig', {'genero': 'm'}), (u'Whitetip', {'genero': 'f'}), (u'Bumper', {'genero': 'NA'}), (u'Ripplefluke', {'genero': 'f'}), (u'Notch', {'genero': 'f'}), (u'Kringel', {'genero': 'm'}), (u'TSN83', {'genero': 'm'}), (u'SN90', {'genero': 'NA'}), (u'TR99', {'genero': 'f'}), (u'SN96', {'genero': 'm'}), (u'SN100', {'genero': 'm'}), (u'TR120', {'genero': 'm'}), (u'Fish', {'genero': 'm'}), (u'SN4', {'genero': 'f'}), (u'Zipfel', {'genero': 'm'}), (u'Hook', {'genero': 'f'}), (u'PL', {'genero': 'm'}), (u'MN83', {'genero': 'm'}), (u'Patchback', {'genero': 'm'}), (u'Oscar', {'genero': 'f'}), (u'MN105', {'genero': 'm'}), (u'Scabs', {'genero': 'f'}), (u'TR88', {'genero': 'm'}), (u'Gallatin', {'genero': 'f'}), (u'Upbang', {'genero': 'm'})])
#
# (' Abajo:', [(u'Haecksel', {'genero': 'f'}), (u'Web', {'genero': 'm'}), (u'Jet', {'genero': 'f'}), (u'SMN5', {'genero': 'f'}), (u'DN16', {'genero': 'f'}), (u'Shmuddel', {'genero': 'm'}), (u'Cross', {'genero': 'f'}), (u'Topless', {'genero': 'm'}), (u'Beescratch', {'genero': 'm'}), (u'CCL', {'genero': 'm'}), (u'Quasi', {'genero': 'm'}), (u'MN60', {'genero': 'm'}), (u'Feather', {'genero': 'f'}), (u'Wave', {'genero': 'f'}), (u'SN9', {'genero': 'f'}), (u'Fork', {'genero': 'm'}), (u'Mus', {'genero': 'NA'}), (u'DN63', {'genero': 'm'}), (u'DN21', {'genero': 'f'}), (u'SN89', {'genero': 'f'}), (u'MN23', {'genero': 'm'}), (u'Stripes', {'genero': 'm'}), (u'Jonah', {'genero': 'm'}), (u'Zap', {'genero': 'm'}), (u'Five', {'genero': 'f'}), (u'Beak', {'genero': 'm'}), (u'Vau', {'genero': 'm'}), (u'Knit', {'genero': 'f'}), (u'TSN103', {'genero': 'NA'}), (u'Grin', {'genero': 'f'}), (u'TR82', {'genero': 'f'}), (u'TR77', {'genero': 'm'}), (u'Double', {'genero': 'm'}), (u'Number1', {'genero': 'm'}), (u'Thumper', {'genero': 'f'}), (u'SN63', {'genero': 'm'}), (u'Trigger', {'genero': 'f'}), (u'Zig', {'genero': 'f'}), (u'Whitetip', {'genero': 'm'}), (u'Bumper', {'genero': 'm'}), (u'Ripplefluke', {'genero': 'm'}), (u'Notch', {'genero': 'm'}), (u'Kringel', {'genero': 'm'}), (u'TSN83', {'genero': 'm'}), (u'SN90', {'genero': 'f'}), (u'TR99', {'genero': 'm'}), (u'SN96', {'genero': 'm'}), (u'SN100', {'genero': 'f'}), (u'TR120', {'genero': 'm'}), (u'Fish', {'genero': 'f'}), (u'SN4', {'genero': 'm'}), (u'Zipfel', {'genero': 'm'}), (u'Hook', {'genero': 'f'}), (u'PL', {'genero': 'f'}), (u'MN83', {'genero': 'm'}), (u'Patchback', {'genero': 'm'}), (u'Oscar', {'genero': 'm'}), (u'MN105', {'genero': 'm'}), (u'Scabs', {'genero': 'f'}), (u'TR88', {'genero': 'NA'}), (u'Gallatin', {'genero': 'f'}), (u'Upbang', {'genero': 'm'})])
#
# (' Abajo:', [(u'Haecksel', {'genero': 'm'}), (u'Web', {'genero': 'NA'}), (u'Jet', {'genero': 'm'}), (u'SMN5', {'genero': 'm'}), (u'DN16', {'genero': 'f'}), (u'Shmuddel', {'genero': 'm'}), (u'Cross', {'genero': 'm'}), (u'Topless', {'genero': 'f'}), (u'Beescratch', {'genero': 'm'}), (u'CCL', {'genero': 'f'}), (u'Quasi', {'genero': 'NA'}), (u'MN60', {'genero': 'm'}), (u'Feather', {'genero': 'f'}), (u'Wave', {'genero': 'm'}), (u'SN9', {'genero': 'm'}), (u'Fork', {'genero': 'f'}), (u'Mus', {'genero': 'f'}), (u'DN63', {'genero': 'm'}), (u'DN21', {'genero': 'm'}), (u'SN89', {'genero': 'NA'}), (u'MN23', {'genero': 'f'}), (u'Stripes', {'genero': 'f'}), (u'Jonah', {'genero': 'f'}), (u'Zap', {'genero': 'm'}), (u'Five', {'genero': 'm'}), (u'Beak', {'genero': 'f'}), (u'Vau', {'genero': 'f'}), (u'Knit', {'genero': 'm'}), (u'TSN103', {'genero': 'm'}), (u'Grin', {'genero': 'f'}), (u'TR82', {'genero': 'f'}), (u'TR77', {'genero': 'f'}), (u'Double', {'genero': 'm'}), (u'Number1', {'genero': 'm'}), (u'Thumper', {'genero': 'f'}), (u'SN63', {'genero': 'f'}), (u'Trigger', {'genero': 'm'}), (u'Zig', {'genero': 'm'}), (u'Whitetip', {'genero': 'm'}), (u'Bumper', {'genero': 'f'}), (u'Ripplefluke', {'genero': 'm'}), (u'Notch', {'genero': 'm'}), (u'Kringel', {'genero': 'm'}), (u'TSN83', {'genero': 'f'}), (u'SN90', {'genero': 'f'}), (u'TR99', {'genero': 'f'}), (u'SN96', {'genero': 'f'}), (u'SN100', {'genero': 'm'}), (u'TR120', {'genero': 'm'}), (u'Fish', {'genero': 'm'}), (u'SN4', {'genero': 'f'}), (u'Zipfel', {'genero': 'm'}), (u'Hook', {'genero': 'm'}), (u'PL', {'genero': 'f'}), (u'MN83', {'genero': 'm'}), (u'Patchback', {'genero': 'm'}), (u'Oscar', {'genero': 'm'}), (u'MN105', {'genero': 'f'}), (u'Scabs', {'genero': 'm'}), (u'TR88', {'genero': 'm'}), (u'Gallatin', {'genero': 'm'}), (u'Upbang', {'genero': 'm'})])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-6e058fc998ff> in <module>()
#      11     print(" Abajo:",list(G.nodes(data=True)))
#      12     j+=1
# ---> 13 comp = nx.girvan_newman(G)
#
# AttributeError: 'module' object has no attribute 'girvan_newman'
